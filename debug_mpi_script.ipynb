# %%
import os
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt

# %%
# Open the HDF5 file
filename ='/exafs/400NVX2/cmacmahon/spectra_data/cl_ee_2tasks_40samples_seed456.h5'

with h5.File(filename, 'r') as f:
    # List all groups
    print("Keys: %s" % f.keys())
    
    # Get the first group
    a_group_key = list(f.keys())[0]
    
    # Get the data from the group
    data = f[a_group_key][:]
    
    # Print the shape of the data
    print(data.shape)

    X_train = f['X_train'][:5]
    y_train = f['y_train'][:5]
    
plt.plot(y_train[0,0,:])
plt.yscale('log')
# Out:
# Keys: <KeysViewHDF5 ['X_train', 'dndz', 'dndz_params', 'y_train', 'z']>
# (2, 40, 10)
